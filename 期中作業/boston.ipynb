# %%
from sklearn import datasets, metrics
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
# 讀取boston資料集
boston = datasets.load_boston()


# 切分訓練集/測試集
x_train, x_test, y_train, y_test = train_test_split(boston.data, boston.target, test_size=0.25, random_state=4)

# 建立模型 (使用 20 顆樹，每棵樹的最大深度為 4)
clf = RandomForestRegressor(
      n_estimators=20, 
      max_depth=4,
      criterion = 'mse',
      min_samples_split = 2,
      min_samples_leaf = 1,
)
    

# 訓練模型
clf.fit(x_train, y_train)

# 預測測試集
y_pred = clf.predict(x_test)

imp=clf.feature_importances_
names=boston.feature_names

print(names)
print("Feature importance: ", imp)
zip(imp,names)
imp, names= zip(*sorted(zip(imp,names)))
plt.barh(range(len(names)),imp,align='center')
plt.yticks(range(len(names)),names)
plt.xlabel('Importance of Features')
plt.ylabel('Features')
plt.title('Importance of Each Feature')
plt.show()
# Out:
# ['CRIM' 'ZN' 'INDUS' 'CHAS' 'NOX' 'RM' 'AGE' 'DIS' 'RAD' 'TAX' 'PTRATIO'
#  'B' 'LSTAT']
# Feature importance:  [0.0646203  0.         0.00213855 0.00194739 0.02035978 0.46483526
#  0.0084653  0.03358079 0.00095244 0.00668528 0.00647985 0.00574306
#  0.384192  ]

# %%
# 讀取boston資料集
boston = datasets.load_boston()


# 切分訓練集/測試集
x_train, x_test, y_train, y_test = train_test_split(boston.data, boston.target, test_size=0.25, random_state=4)

# 建立模型 (使用 200 顆樹，每棵樹的最大深度為 40)
clf = RandomForestRegressor(
      n_estimators=200, 
      max_depth=40,
      criterion = 'mse',
      min_samples_split = 2,
      min_samples_leaf = 1,
)
    

# 訓練模型
clf.fit(x_train, y_train)

# 預測測試集
y_pred = clf.predict(x_test)

imp=clf.feature_importances_
names=boston.feature_names

print(names)
print("Feature importance: ", imp)
zip(imp,names)
imp, names= zip(*sorted(zip(imp,names)))
plt.barh(range(len(names)),imp,align='center')
plt.yticks(range(len(names)),names)
plt.xlabel('Importance of Features')
plt.ylabel('Features')
plt.title('Importance of Each Feature')
plt.show()
# Out:
# ['CRIM' 'ZN' 'INDUS' 'CHAS' 'NOX' 'RM' 'AGE' 'DIS' 'RAD' 'TAX' 'PTRATIO'
#  'B' 'LSTAT']
# Feature importance:  [0.05418856 0.00128146 0.00741566 0.00221924 0.0182443  0.44414743
#  0.01291734 0.05192255 0.00295213 0.01741226 0.02083012 0.01403979
#  0.35242915]
