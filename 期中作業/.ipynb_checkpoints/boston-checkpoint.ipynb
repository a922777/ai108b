# %%
from sklearn import datasets, metrics
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
# 讀取房地產資料集
boston = datasets.load_boston()

# 切分訓練集/測試集
x_train, x_test, y_train, y_test = train_test_split(boston.data, boston.target, test_size=0.25, random_state=4)

# 建立模型 (使用 20 顆樹，每棵樹的最大深度為 4)
clf = RandomForestRegressor(
      n_estimators=20, 
      max_depth=4,
      criterion = 'mse',
      min_samples_split = 2,
      min_samples_leaf = 1,
)
    
# 訓練模型
clf.fit(x_train, y_train)

# 預測測試集
y_pred = clf.predict(x_test)

imp=clf.feature_importances_
names=boston.feature_names

print(names)
print("Feature importance: ", imp)
zip(imp,names)
imp, names= zip(*sorted(zip(imp,names)))
plt.barh(range(len(names)),imp,align='center')
plt.yticks(range(len(names)),names)
plt.xlabel('Importance of Features')
plt.ylabel('Features')
plt.title('Importance of Each Feature')
plt.show()
# Out:
# ['CRIM' 'ZN' 'INDUS' 'CHAS' 'NOX' 'RM' 'AGE' 'DIS' 'RAD' 'TAX' 'PTRATIO'
#  'B' 'LSTAT']
# Feature importance:  [0.05034809 0.         0.00390348 0.         0.00617033 0.43195451
#  0.00785144 0.05922864 0.00100395 0.00580605 0.01338063 0.00630438
#  0.41404851]

# %%
# 讀取房地產資料集
boston = datasets.load_boston()

# 切分訓練集/測試集
x_train, x_test, y_train, y_test = train_test_split(boston.data, boston.target, test_size=0.25, random_state=4)

# 建立模型 (使用 200 顆樹，每棵樹的最大深度為 40)
clf = RandomForestRegressor(
      n_estimators=200, 
      max_depth=40,
      criterion = 'mse',
      min_samples_split = 2,
      min_samples_leaf = 1,
)
    
# 訓練模型
clf.fit(x_train, y_train)

# 預測測試集
y_pred = clf.predict(x_test)

imp=clf.feature_importances_
names=boston.feature_names

print(names)
print("Feature importance: ", imp)
zip(imp,names)
imp, names= zip(*sorted(zip(imp,names)))
plt.barh(range(len(names)),imp,align='center')
plt.yticks(range(len(names)),names)
plt.xlabel('Importance of Features')
plt.ylabel('Features')
plt.title('Importance of Each Feature')
plt.show()
# Out:
# ['CRIM' 'ZN' 'INDUS' 'CHAS' 'NOX' 'RM' 'AGE' 'DIS' 'RAD' 'TAX' 'PTRATIO'
#  'B' 'LSTAT']
# Feature importance:  [0.05697603 0.00105945 0.00693822 0.00223304 0.01905553 0.45573421
#  0.01364554 0.05334144 0.00371476 0.01736677 0.01812302 0.01094371
#  0.34086827]
