# %%
from sklearn import datasets, metrics
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
# 讀取葡萄酒資料集
wine = datasets.load_wine()

# 切分訓練集/測試集
x_train, x_test, y_train, y_test = train_test_split(wine.data, wine.target, test_size=0.1, random_state=4)

# 建立模型 (使用 20 顆樹，每棵樹的最大深度為 4)
clf = RandomForestRegressor(
      n_estimators = 20, 
      criterion = 'mse',
      max_depth = 4,
      min_samples_split = 2,
      min_samples_leaf = 1,
)
    
# 訓練模型
clf.fit(x_train, y_train)

# 預測測試集
y_pred = clf.predict(x_test)

imp=clf.feature_importances_
names=wine.feature_names

print(names)
print("Feature importance: ", imp)
zip(imp,names)
imp, names= zip(*sorted(zip(imp,names)))
plt.barh(range(len(names)),imp,align='center')
plt.yticks(range(len(names)),names)
plt.xlabel('Importance of Features')
plt.ylabel('Features')
plt.title('Importance of Each Feature')
plt.show()
# Out:
# ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Feature importance:  [0.01665871 0.00103929 0.00290965 0.0046075  0.00866044 0.
#  0.45896397 0.         0.00191229 0.07816119 0.02779947 0.17957394
#  0.21971355]

# %%
# 讀取葡萄酒資料集
wine = datasets.load_wine()

# 切分訓練集/測試集
x_train, x_test, y_train, y_test = train_test_split(wine.data, wine.target, test_size=0.1, random_state=4)

# 建立模型 (使用 200 顆樹，每棵樹的最大深度為 40)
clf = RandomForestRegressor(
      n_estimators = 200, 
      criterion = 'mse',
      max_depth = 40,
      min_samples_split = 2,
      min_samples_leaf = 1,
)  

# 訓練模型
clf.fit(x_train, y_train)

# 預測測試集
y_pred = clf.predict(x_test)

# 預測測試集
y_pred = clf.predict(x_test)

imp=clf.feature_importances_
names=wine.feature_names

print(names)
print("Feature importance: ", imp)
zip(imp,names)
imp, names= zip(*sorted(zip(imp,names)))
plt.barh(range(len(names)),imp,align='center')
plt.yticks(range(len(names)),names)
plt.xlabel('Importance of Features')
plt.ylabel('Features')
plt.title('Importance of Each Feature')
plt.show()
# Out:
# ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Feature importance:  [0.03543786 0.00291098 0.002002   0.00440859 0.00686947 0.00174995
#  0.43553575 0.00050236 0.0023203  0.09729064 0.04009559 0.10193532
#  0.2689412 ]
